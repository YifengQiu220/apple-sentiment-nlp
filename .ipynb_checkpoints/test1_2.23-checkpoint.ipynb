# %% [markdown]
# import spacy
#
# # Load the English NLP model
# nlp = spacy.load("en_core_web_sm")
#
# print("SpaCy is ready! ✅")

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv(r"C:\Users\laifu\Desktop\SU 25spr\project gdp\data\sample_ccall.csv", encoding="ISO-8859-1")



# Show first few rows
df.head()
# Out:
#                   companyid   keydevid  transcriptid  \
# 0                     24937  2710235.0         135.0
# 1                     24937  2710235.0         135.0
# 2                     24937  2710235.0         135.0
# 3                     24937  2710235.0         135.0
# 4  (Operator Instructions)         NaN           NaN
#
#                                          headline mostimportantdateutc  \
# 0  Apple Inc., Q3 2006 Earnings Call, Jul-19-2006            19JUL2006
# 1  Apple Inc., Q3 2006 Earnings Call, Jul-19-2006            19JUL2006
# 2  Apple Inc., Q3 2006 Earnings Call, Jul-19-2006            19JUL2006
# 3  Apple Inc., Q3 2006 Earnings Call, Jul-19-2006            19JUL2006
# 4                                             NaN                  NaN
#
#   mostimportanttimeutc  keydeveventtypeid keydeveventtypename companyname  \
# 0             21:00:00               48.0      Earnings Calls  Apple Inc.
# 1             21:00:00               48.0      Earnings Calls  Apple Inc.
# 2             21:00:00               48.0      Earnings Calls  Apple Inc.
# 3             21:00:00               48.0      Earnings Calls  Apple Inc.
# 4                  NaN                NaN                 NaN         NaN
#
#    transcriptcollectiontypeid  ... transcriptcomponenttypeid  \
# 0                         6.0  ...                       1.0
# 1                         6.0  ...                       2.0
# 2                         6.0  ...                       2.0
# 3                         6.0  ...                       7.0
# 4                         NaN  ...                       NaN
#
#             transcriptcomponenttypename transcriptpersonid  \
# 0         Presentation Operator Message                1.0
# 1                      Presenter Speech            10581.0
# 2                      Presenter Speech            10627.0
# 3  Question and Answer Operator Message                1.0
# 4                                   NaN                NaN
#
#   transcriptpersonname proid  companyofperson  speakertypeid  speakertypename  \
# 0             Operator   NaN              NaN            1.0         Operator
# 1         Nancy Paxton   NaN              NaN            2.0       Executives
# 2    Peter Oppenheimer   NaN              NaN            2.0       Executives
# 3             Operator   NaN              NaN            1.0         Operator
# 4                  NaN   NaN              NaN            NaN              NaN
#
#                                 componenttextpreview word_count
# 0  Good day, and welcome to this Apple Computer t...       48.0
# 1  Thank you. Good afternoon, and thanks to every...      195.0
# 2  Thank you, Nancy. Thank you for joining us. We...     1326.0
# 3                                        Thank you.         NaN
# 4                                                NaN        NaN
#
# [5 rows x 28 columns]

# %%
df.isnull().sum()
# Out:
# companyid                           557
# keydevid                             33
# transcriptid                        633
# headline                            633
# mostimportantdateutc                633
# mostimportanttimeutc                633
# keydeveventtypeid                   633
# keydeveventtypename                 633
# companyname                         633
# transcriptcollectiontypeid          633
# transcriptcollectiontypename        633
# transcriptpresentationtypeid        633
# transcriptpresentationtypename      633
# transcriptcreationdate_utc          633
# transcriptcreationtime_utc          633
# audiolengthsec                     3024
# transcriptcomponentid               633
# componentorder                      633
# transcriptcomponenttypeid           633
# transcriptcomponenttypename         633
# transcriptpersonid                  633
# transcriptpersonname                633
# proid                              7062
# companyofperson                   16016
# speakertypeid                       633
# speakertypename                     633
# componenttextpreview                633
# word_count                         1233
# dtype: int64

# %%
# Show all column names
print(df.columns)
# Out:
# Index(['companyid', 'keydevid', 'transcriptid', 'headline',
#        'mostimportantdateutc', 'mostimportanttimeutc', 'keydeveventtypeid',
#        'keydeveventtypename', 'companyname', 'transcriptcollectiontypeid',
#        'transcriptcollectiontypename', 'transcriptpresentationtypeid',
#        'transcriptpresentationtypename', 'transcriptcreationdate_utc',
#        'transcriptcreationtime_utc', 'audiolengthsec', 'transcriptcomponentid',
#        'componentorder', 'transcriptcomponenttypeid',
#        'transcriptcomponenttypename', 'transcriptpersonid',
#        'transcriptpersonname', 'proid', 'companyofperson', 'speakertypeid',
#        'speakertypename', 'componenttextpreview', 'word_count'],
#       dtype='object')

# %%
# Keep only relevant columns
df = df[['mostimportantdateutc', 'mostimportanttimeutc', 'transcriptpersonname', 'speakertypename', 'componenttextpreview']]

# Display the first few rows
df.head()
# Out:
#   mostimportantdateutc mostimportanttimeutc transcriptpersonname  \
# 0            19JUL2006             21:00:00             Operator
# 1            19JUL2006             21:00:00         Nancy Paxton
# 2            19JUL2006             21:00:00    Peter Oppenheimer
# 3            19JUL2006             21:00:00             Operator
# 4                  NaN                  NaN                  NaN
#
#   speakertypename                               componenttextpreview
# 0        Operator  Good day, and welcome to this Apple Computer t...
# 1      Executives  Thank you. Good afternoon, and thanks to every...
# 2      Executives  Thank you, Nancy. Thank you for joining us. We...
# 3        Operator                                        Thank you.
# 4             NaN                                                NaN

# %%
# Check missing values again
df.isnull().sum()
# Out:
# mostimportantdateutc    633
# mostimportanttimeutc    633
# transcriptpersonname    633
# speakertypename         633
# componenttextpreview    633
# dtype: int64

# %%
# Check total number of rows
df.shape
# Out:
# (16956, 5)

# %%
# Show rows with missing values
df[df.isnull().any(axis=1)].head(10)
# Out:
#    mostimportantdateutc mostimportanttimeutc transcriptpersonname  \
# 4                   NaN                  NaN                  NaN
# 5                   NaN                  NaN                  NaN
# 6                   NaN                  NaN                  NaN
# 11                  NaN                  NaN                  NaN
# 16                  NaN                  NaN                  NaN
# 19                  NaN                  NaN                  NaN
# 27                  NaN                  NaN                  NaN
# 30                  NaN                  NaN                  NaN
# 37                  NaN                  NaN                  NaN
# 39                  NaN                  NaN                  NaN
#
#    speakertypename componenttextpreview
# 4              NaN                  NaN
# 5              NaN                  NaN
# 6              NaN                  NaN
# 11             NaN                  NaN
# 16             NaN                  NaN
# 19             NaN                  NaN
# 27             NaN                  NaN
# 30             NaN                  NaN
# 37             NaN                  NaN
# 39             NaN                  NaN

# %%
# Drop rows where all values are NaN
df = df.dropna(how="all")

# Verify the shape after dropping
df.shape
# Out:
# (16323, 5)

# %%
# Check remaining missing values
df.isnull().sum()
# Out:
# mostimportantdateutc    0
# mostimportanttimeutc    0
# transcriptpersonname    0
# speakertypename         0
# componenttextpreview    0
# dtype: int64

# %%
import spacy

# Load the SpaCy English model
nlp = spacy.load("en_core_web_sm")

# Function to clean text
def preprocess_text(text):
    doc = nlp(text)  # Process the text with SpaCy
    cleaned_tokens = [
        token.lemma_.lower()  # Lemmatize and lowercase
        for token in doc
        if not token.is_stop and not token.is_punct and not token.is_space  # Remove stopwords, punctuation, spaces
    ]
    return " ".join(cleaned_tokens)  # Join tokens back into a string

# Apply preprocessing to the transcript text column
df["cleaned_text"] = df["componenttextpreview"].apply(preprocess_text)

# Display the first few rows
df[["componenttextpreview", "cleaned_text"]].head()
# Out:
#                                 componenttextpreview  \
# 0  Good day, and welcome to this Apple Computer t...
# 1  Thank you. Good afternoon, and thanks to every...
# 2  Thank you, Nancy. Thank you for joining us. We...
# 3                                        Thank you.
# 7  If you could talk, to the extent you can, abou...
#
#                                         cleaned_text
# 0  good day welcome apple computer quarter financ...
# 1  thank good afternoon thank join speak today ap...
# 2  thank nancy thank join pleased report second h...
# 3                                              thank
# 7  talk extent view balance year press release ta...

# %%
df.to_csv("cleaned_transcripts.csv", index=False)

# %%
import pandas as pd

# Load the cleaned data
df_cleaned = pd.read_csv("cleaned_transcripts.csv")

# Display the first few rows
df_cleaned.head()


#note meeting
#stop words, implement my own mini version of words. write a words document report.
# Out:
#   mostimportantdateutc mostimportanttimeutc transcriptpersonname  \
# 0            19JUL2006             21:00:00             Operator
# 1            19JUL2006             21:00:00         Nancy Paxton
# 2            19JUL2006             21:00:00    Peter Oppenheimer
# 3            19JUL2006             21:00:00             Operator
# 4            19JUL2006             21:00:00          Andrew Neff
#
#   speakertypename                               componenttextpreview  \
# 0        Operator  Good day, and welcome to this Apple Computer t...
# 1      Executives  Thank you. Good afternoon, and thanks to every...
# 2      Executives  Thank you, Nancy. Thank you for joining us. We...
# 3        Operator                                        Thank you.
# 4        Analysts  If you could talk, to the extent you can, abou...
#
#                                         cleaned_text
# 0  good day welcome apple computer quarter financ...
# 1  thank good afternoon thank join speak today ap...
# 2  thank nancy thank join pleased report second h...
# 3                                              thank
# 4  talk extent view balance year press release ta...

# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Using cached transformers-4.49.0-py3-none-any.whl.metadata (44 kB)
# Requirement already satisfied: filelock in c:\users\laifu\anaconda3\lib\site-packages (from transformers) (3.13.1)
# Collecting huggingface-hub<1.0,>=0.26.0 (from transformers)
#   Downloading huggingface_hub-0.29.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.17 in c:\users\laifu\anaconda3\lib\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\laifu\anaconda3\lib\site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\laifu\anaconda3\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\laifu\anaconda3\lib\site-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in c:\users\laifu\anaconda3\lib\site-packages (from transformers) (2.32.3)
# Collecting tokenizers<0.22,>=0.21 (from transformers)
#   Downloading tokenizers-0.21.0-cp39-abi3-win_amd64.whl.metadata (6.9 kB)
# Collecting safetensors>=0.4.1 (from transformers)
#   Downloading safetensors-0.5.2-cp38-abi3-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: tqdm>=4.27 in c:\users\laifu\anaconda3\lib\site-packages (from transformers) (4.66.5)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\laifu\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.26.0->transformers) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\laifu\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.26.0->transformers) (4.11.0)
# Requirement already satisfied: colorama in c:\users\laifu\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\laifu\anaconda3\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\laifu\anaconda3\lib\site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\laifu\anaconda3\lib\site-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\laifu\anaconda3\lib\site-packages (from requests->transformers) (2024.12.14)
# Downloading transformers-4.49.0-py3-none-any.whl (10.0 MB)
#    ---------------------------------------- 0.0/10.0 MB ? eta -:--:--
#    --------- ------------------------------ 2.4/10.0 MB 11.2 MB/s eta 0:00:01
#    ------------------ --------------------- 4.7/10.0 MB 11.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.1/10.0 MB 11.8 MB/s eta 0:00:01
#    -------------------------------------- - 9.7/10.0 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------- 10.0/10.0 MB 11.5 MB/s eta 0:00:00
# Downloading huggingface_hub-0.29.1-py3-none-any.whl (468 kB)
# Downloading safetensors-0.5.2-cp38-abi3-win_amd64.whl (303 kB)
# Downloading tokenizers-0.21.0-cp39-abi3-win_amd64.whl (2.4 MB)
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ---------------------------------------  2.4/2.4 MB 12.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.4/2.4 MB 11.4 MB/s eta 0:00:00
# Installing collected packages: safetensors, huggingface-hub, tokenizers, transformers
# Successfully installed huggingface-hub-0.29.1 safetensors-0.5.2 tokenizers-0.21.0 transformers-4.49.0

# %%
import torch
print(torch.cuda.is_available())  # Should print True
print(torch.cuda.device_count())  # Should print 1 (or more if you have multiple GPUs)
print(torch.cuda.get_device_name(0))  # Should print 'NVIDIA RTX 4090'
# Out:
# True
# 1
# NVIDIA GeForce RTX 4090

# %%
import torch
print(torch.__version__)  # Should print the installed PyTorch version
print(torch.cuda.is_available())  # Should print True
# Out:
# 2.5.1+cu121
# True

# %%
from transformers import is_torch_available
print("Is PyTorch available in transformers?", is_torch_available())
# Out:
# Is PyTorch available in transformers? True

# %%
from transformers import pipeline

# Load the sentiment analysis pipeline
sentiment_model = pipeline("sentiment-analysis")

# Test on a sample sentence
print(sentiment_model("The company's performance has been outstanding this quarter!"))
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# C:\Users\laifu\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:142: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\laifu\.cache\huggingface\hub\models--distilbert--distilbert-base-uncased-finetuned-sst-2-english. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Device set to use cuda:0
# [{'label': 'POSITIVE', 'score': 0.9998581409454346}]

# %%
# Filter dataset for only Tim Cook's statements
tim_cook_df = df_cleaned[df_cleaned["transcriptpersonname"] == "Tim Cook"]

# Display the first few rows
tim_cook_df.head()
# Out:
#    mostimportantdateutc mostimportanttimeutc transcriptpersonname  \
# 10            19JUL2006             21:00:00             Tim Cook
# 16            19JUL2006             21:00:00             Tim Cook
# 56            19JUL2006             21:00:00             Tim Cook
# 61            19JUL2006             21:00:00             Tim Cook
# 70            19JUL2006             21:00:00             Tim Cook
#
#    speakertypename                               componenttextpreview  \
# 10      Executives  As Peter said earlier, the component pricing w...
# 16      Executives  In terms of what we saw across the quarter, on...
# 56      Executives  In regards to the MacBook, we shipped a signif...
# 61      Executives                           It was not significant.
# 70      Executives  Rebecca, the main one that we are running righ...
#
#                                          cleaned_text
# 10  peter say early component pricing favorable q3...
# 16  term see quarter announce macbook begin ship s...
# 56  regard macbook ship significant number macbook...
# 61                                        significant
# 70  rebecca main run right bestbuy store half appl...

# %%
# Apply sentiment analysis to Tim Cook's statements
tim_cook_df.loc[:, "sentiment"] = tim_cook_df["cleaned_text"].apply(lambda text: sentiment_model(text)[0])


# Split sentiment into label and score
tim_cook_df["sentiment_label"] = tim_cook_df["sentiment"].apply(lambda x: x["label"])
tim_cook_df["sentiment_score"] = tim_cook_df["sentiment"].apply(lambda x: x["score"])

# Display the results
tim_cook_df[["cleaned_text", "sentiment_label", "sentiment_score"]].head()
# Out:
# C:\Users\laifu\AppData\Local\Temp\ipykernel_38644\3775728794.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tim_cook_df["sentiment_label"] = tim_cook_df["sentiment"].apply(lambda x: x["label"])
# C:\Users\laifu\AppData\Local\Temp\ipykernel_38644\3775728794.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tim_cook_df["sentiment_score"] = tim_cook_df["sentiment"].apply(lambda x: x["score"])
#                                          cleaned_text sentiment_label  \
# 10  peter say early component pricing favorable q3...        POSITIVE
# 16  term see quarter announce macbook begin ship s...        NEGATIVE
# 56  regard macbook ship significant number macbook...        POSITIVE
# 61                                        significant        POSITIVE
# 70  rebecca main run right bestbuy store half appl...        NEGATIVE
#
#     sentiment_score
# 10         0.986087
# 16         0.994600
# 56         0.773026
# 61         0.999787
# 70         0.995480

# %%
executives_df = df_cleaned[df_cleaned["speakertypename"] == "Executives"]

# %%
# Ensure cleaned_text is a string and remove NaN values
executives_df = executives_df.dropna(subset=["cleaned_text"])  # Drop NaN rows
executives_df = executives_df[executives_df["cleaned_text"].str.strip() != ""]  # Remove empty strings
executives_df["cleaned_text"] = executives_df["cleaned_text"].astype(str)  # Convert everything to string

# %%
executives_df.loc[:, "sentiment"] = executives_df["cleaned_text"].apply(lambda text: sentiment_model(text)[0])
executives_df.loc[:, "sentiment_label"] = executives_df["sentiment"].apply(lambda x: x["label"])
executives_df.loc[:, "sentiment_score"] = executives_df["sentiment"].apply(lambda x: x["score"])

# %%
executives_df[["cleaned_text", "sentiment_label", "sentiment_score"]].head()
# Out:
#                                         cleaned_text sentiment_label  \
# 1  thank good afternoon thank join speak today ap...        POSITIVE
# 2  thank nancy thank join pleased report second h...        POSITIVE
# 5  andy know talk unannounced product limit tell ...        POSITIVE
# 6                                thank andy question        POSITIVE
# 9  start generally tim provide color commodity en...        NEGATIVE
#
#    sentiment_score
# 1         0.999519
# 2         0.999432
# 5         0.662090
# 6         0.999160
# 9         0.967484

# %%
executives_df.to_csv("executives_sentiment.csv", index=False)
